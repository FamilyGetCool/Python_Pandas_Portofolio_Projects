# %%
#                                    Detail
#1. Invoice id: Computer generated sales slip invoice identification number
#2. Branch: Branch of supercenter (3 branches are available identified by A, B and C).
#3. City: Location of supercenters
#4. Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#5. Gender: Gender type of customer
#6. Product line: General item categorization groups - Electronic accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
#7. Unit price: Price of each product in $
#8. Quantity: Number of products purchased by customer
#9. Tax: 5% tax fee for customer buying
#10. Total: Total price including tax
#11. Date: Date of purchase (Record available from January 2019 to March 2019)
#12. Time: Purchase time (10am to 9pm)
#13. Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
#14. COGS: Cost of goods sold
#15. Gross margin percentage: Gross margin percentage
#16. Gross income: Gross income
#17. Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('Data_Supermarket Sales.csv', parse_dates=['Date'])
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### 1. Display the Top 5 Rows

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# ### 2. Display the Last 5 Rows

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675 2019-01-29  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320 2019-02-09  13:22     Cash
# 998       65.82         1   3.2910    69.1110 2019-02-22  15:33     Cash
# 999       88.34         7  30.9190   649.2990 2019-02-18  13:28     Cash
#
# ...

# %% [markdown]
# ### 3. Print 5 Random Rows

# %%
df.sample(n=5, random_state=8787)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 689  305-03-2383      A     Yangon        Normal  Female   Food and beverages
# 390  541-89-9860      C  Naypyitaw        Member  Female  Fashion accessories
# 233  269-04-5750      B   Mandalay        Member    Male  Fashion accessories
# 168  796-32-9050      A     Yangon        Normal    Male   Food and beverages
# 726  442-44-6497      C  Naypyitaw        Member    Male   Home and lifestyle
#
#      Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 689       67.10         3  10.0650  211.3650 2019-02-15  10:36         Cash
# 390       80.48         3  12.0720  253.5120 2019-02-15  12:31         Cash
# 233       73.82         4  14.7640  310.0440 2019-02-21  18:31         Cash
# 168       51.28         6  15.3840  323.0640 2019-01-19  16:31         Cash
# 726       55.57         3   8.3355  175.0455 2019-01-08  11:42  Credit card
#
# ...

# %% [markdown]
# ### 4. Find Shape of the Dataset

# %%
print('Rows:', df.shape[0])
print('Columns:', df.shape[1])
# Out:
# Rows: 1000
# Columns: 17

# %% [markdown]
# ### 5. Check for Null Values

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# ### 6. Acquire Information of the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %% [markdown]
# ### 7. Acquire Overall Statistics of the Dataset

# %%
df.describe(include='all')
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
# first           NaN    NaN     NaN           NaN     NaN                  NaN
# last            NaN    NaN     NaN           NaN     NaN                  NaN
# mean            NaN    NaN     NaN           NaN     NaN                  NaN
# std             NaN    NaN     NaN           NaN     NaN                  NaN
# min             NaN    NaN     NaN           NaN     NaN                  NaN
# 25%             NaN    NaN     NaN           NaN     NaN                  NaN
# 50%             NaN    NaN     NaN           NaN     NaN                  NaN
# ...

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### 1. Find the Total Sales of Each Branch

# %%
plt.figure(figsize=(6,6))
df.groupby('Branch')['Total'].sum().plot(kind='pie', legend='Branch', autopct='%1.1f%%')
plt.title('Total Sales by Branch in Percentage', fontsize=10)
plt.show()

# %% [markdown]
# ### 2. Find the Most Popular Payment Method Used by Customer

# %%
df['Payment'].value_counts().sort_values(ascending=False).reset_index()
# Out:
#          index  Payment
# 0      Ewallet      345
# 1         Cash      344
# 2  Credit card      311

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Payment', data=df)
plt.title('Count of Payment Methods Used by Customer')
plt.show()

# %%
plt.figure(figsize=(10,5))
df['Payment'].value_counts().plot(kind='bar')
plt.title('Count of Payment Methods Used by Customer')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### 3. Find the Distribution of Customer Ratings

# %%
sns.displot(df['Rating'], kde=True)
plt.title('Distribution of Customer Ratings', fontsize=13)
plt.show()

# %% [markdown]
# ### 4. Find the Distribution of Cost of Goods Sold

# %%
sns.displot(df['cogs'], kde=True)
plt.title('Distribution of Cost of Goods Sold', fontsize=13)
plt.xlabel('Cost of Goods Sold')
plt.show()

# %%
sns.boxplot(df['cogs'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Bivariate and Multivariate Anaylsis

# %% [markdown]
# ### 1. Does the COGS Affect Ratings From Customer?

# %%
# There is little to no relationship between COGS and ratings.

# %%
test1 = df.groupby('Rating')['cogs'].mean().reset_index()

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Rating', y='cogs', data=test1)
plt.title('COGS by Rating', fontsize=15)
plt.xticks(rotation=65)
plt.ylabel('Cost of Goods Sold')
plt.show()

# %%
sns.scatterplot(x='Rating', y='cogs', data=df)
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='cogs'>

# %% [markdown]
# ### 2. Does Gross Income Affect Ratings From Customer?

# %%
# There is little to no relationship between gross income and ratings.

# %%
test2 = df.groupby('Rating')['gross income'].mean().reset_index()
plt.figure(figsize=(15,7))
sns.barplot(x='Rating', y='gross income', data=test2)
plt.title('Gross Income by Rating', fontsize=15)
plt.xticks(rotation=65)
plt.ylabel('Gross Income')
plt.show()

# %%
sns.scatterplot(x='Rating', y='gross income', data=df)
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='gross income'>

# %% [markdown]
# ### 3. Find the Most Profitable Branch by Gross Income

# %%
df.groupby('Branch')['gross income'].sum().plot(kind='pie', autopct='%1.1f%%')
plt.title('Gross Income by Branch')
# Out:
# Text(0.5, 1.0, 'Gross Income by Branch')

# %%
test3 = df.groupby('Branch')['gross income'].sum().sort_values(ascending=False).reset_index()
plt.figure(figsize=(15,7))
sns.barplot(x='Branch',y='gross income', data=test3)
plt.title('Gross Income by Branch', fontsize=17)
plt.xticks(fontsize=15)
plt.xlabel('Branch', fontsize=17)
plt.ylabel('Gross Income', fontsize=17)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.barplot(x='Branch', y='gross income', hue='City', data=df)
plt.title('Gross Income by Branch and City', fontsize=17)
plt.xticks(fontsize=15)
plt.xlabel('Branch', fontsize=17)
plt.ylabel('Gross Income', fontsize=17)
plt.show()

# %% [markdown]
# ### 4. What is the Relationship Between Gender and Gross Income?

# %%
# Female customers contribute more to the gross income then male customers. Moreover, 
# home&lifestyle and food&beverages are the top 2 product lines among female customers;
# on the other hand, the top 2 product lines among male customers are health&beauty and
# sports&travel.

# %%
test4 = df.groupby('Gender')['gross income'].sum().reset_index()
sns.barplot(x='Gender',y='gross income', data=test4)
plt.title('Gross Income by Gender', fontsize=17)
plt.xlabel('Gender', fontsize=17)
plt.ylabel('Gross Income', fontsize=17)
plt.show()

# %%
sns.barplot(x='Gender', y='gross income', hue='Product line', data=df)
plt.legend(loc='lower left', title='Product Line')
plt.title('Gross Income by Gender and Product Line', fontsize=17)
plt.xlabel('Gender', fontsize=17)
plt.ylabel('Gross Income', fontsize=17)
plt.show()

# %% [markdown]
# ### 5. Find the Product Line That Generates the Most Gross Income

# %%
test5 = df.groupby('Product line')['gross income'].sum().sort_values(ascending=False).reset_index()
sns.barplot(x='gross income', y='Product line', data=test5)
plt.title('Gross Income by Product Line', fontsize=17)
plt.xlabel('Gross Income', fontsize=17)
plt.ylabel('Product Line', fontsize=17)
plt.show()

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sns.barplot(x='Product line', y='gross income', hue='Branch',data=df)
plt.title('Gross Income by Product Line and Branch', fontsize=17)
plt.xlabel('Product Line', fontsize=17)
plt.ylabel('Gross Income', fontsize=17)
plt.xticks(rotation=65)
handles, labels = plt.gca().get_legend_handles_labels()
order = [0,2,1]
plt.legend([handles[i] for i in order], [labels[i] for i in order],\
bbox_to_anchor=(1.02, 1), borderaxespad=0, title='Branch')

plt.show()

# %% [markdown]
# ### 7. Find Payment Methods by City (and Customer Type)

# %%
sns.countplot(x='Payment', hue='City', data=df)
# Out:
# <AxesSubplot: xlabel='Payment', ylabel='count'>

# %%
sns.countplot(x='Payment', hue='Customer type', data=df)
# Out:
# <AxesSubplot: xlabel='Payment', ylabel='count'>

# %% [markdown]
# ### 8. Which Product Line Has the Highest Purchase Quantity?

# %%
test6 = df.groupby('Product line')['Quantity'].sum().sort_values(ascending=False).reset_index()
plt.figure(figsize=(10,5))
sns.barplot(x='Product line', y='Quantity', data=test6)
plt.title('Total Purchase Quantity by Product Line', fontsize=17)
plt.xlabel('Product Line', fontsize=17)
plt.ylabel('Quantity', fontsize=17)
plt.xticks(rotation=65)
plt.show()

# %% [markdown]
# ### 9. Display Daily Sales by Day of the Week

# %%
dayofweek = {
    0:'MON',
    1:'TUE',
    2:'WED',
    3:'THUR',
    4:'FRI',
    5:'SAT',
    6:'SUN'
}

# %%
df['Day_of_week'] = df['Date'].dt.day_of_week.map(dayofweek)
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6
#
#   Day_of_week
# 0         SAT
# 1         FRI

# %%
test7 = df.groupby('Day_of_week')['Total'].sum().reset_index()
dow_categories = ['MON','TUE','WED','THUR','FRI','SAT','SUN']
test7['Day_of_week'] = pd.Categorical(test7['Day_of_week'], categories = dow_categories)
test7.sort_values(by = 'Day_of_week')
# Out:
#   Day_of_week       Total
# 1         MON  37899.0780
# 5         TUE  51482.2455
# 6         WED  43731.1350
# 4        THUR  45349.2480
# 0         FRI  43926.3405
# 2         SAT  56120.8095
# 3         SUN  44457.8925

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Day_of_week', y='Total', data=test7)
plt.title('Daily Sales by Day of Week', fontsize=17)
plt.xlabel('Day of Week', fontsize=17)
plt.ylabel('Total Sales', fontsize=17)
plt.show()

# %% [markdown]
# ### 10. Find the Highest Monthly Sales

# %% [markdown]
# #### Method 1

# %%
df['Month'].replace({
    1:"January", 
    2:"February", 
    3:"March"
}, inplace=True)
df.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6
#
#   Day_of_week  Year    Month
# 0         SAT  2019  January
# 1         FRI  2019    March

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Month', y='Total', data=df)
plt.title('Total Sales by Month', fontsize=17)
plt.xlabel('Month', fontsize=17)
plt.ylabel('Total Sales', fontsize=17)
plt.show()

# %% [markdown]
# #### Method 2

# %%
test8 = df.groupby('Month')['Total'].sum().reset_index()
months_categories1 = ['January', 'February', 'March']
test8['Month'] = pd.Categorical(test8['Month'], categories=months_categories1)
test8.sort_values('Month')
# Out:
#       Month       Total
# 1   January  116291.868
# 0  February   97219.374
# 2     March  109455.507

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Month', y='Total', data=test8)
plt.title('Total Sales by Month', fontsize=17)
plt.xlabel('Month', fontsize=17)
plt.ylabel('Total Sales', fontsize=17)
plt.show()
